# %%
import pandas as pd
import numpy as np
import matplotlib as mp

filename = "Data/Sell_In.csv"
df_SI = pd.read_csv(filename)
# Out:
# /var/folders/qm/bcpltlfs7qj3bt894_htm00c0000gn/T/ipykernel_2257/4245869906.py:6: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_SI = pd.read_csv(filename)

# %%
df_SI
# Out:
#               Data Cod. Vendedor Base Cod. Cliente Holding Cod. Cliente  \
# 0       05/01/2023                 33                    -       110009
# 1       05/01/2023                 31                    -        30031
# 2       05/01/2023                 31                    -        30031
# 3       05/01/2023                 31               400024     40002412
# 4       05/01/2023                 31               400024     40002409
# ...            ...                ...                  ...          ...
# 415146  31/12/2024                  -                    -            -
# 415147  31/12/2024                  -                    -            -
# 415148  31/12/2024                  -                    -            -
# 415149  31/12/2024                  -                    -            -
# 415150  31/12/2024                  -                    -            -
#
#                Cod. Artigo  Quantidade  Valor Líq. EUR
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 415151 entries, 0 to 415150
# Data columns (total 7 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Data                  415151 non-null  object
#  1   Cod. Vendedor Base    415151 non-null  object
#  2   Cod. Cliente Holding  415151 non-null  object
#  3   Cod. Cliente          415151 non-null  object
#  4   Cod. Artigo           415151 non-null  object
#  5   Quantidade            415151 non-null  int64
#  6   Valor Líq. EUR        415151 non-null  float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 22.2+ MB

# %%
df_SI.shape
# Out:
# (415151, 7)

# %%
df_SI.head(5)
# Out:
#          Data Cod. Vendedor Base Cod. Cliente Holding Cod. Cliente  \
# 0  05/01/2023                 33                    -       110009
# 1  05/01/2023                 31                    -        30031
# 2  05/01/2023                 31                    -        30031
# 3  05/01/2023                 31               400024     40002412
# 4  05/01/2023                 31               400024     40002409
#
#   Cod. Artigo  Quantidade  Valor Líq. EUR
# 0  OJNYR08S-7           3            30.0
# 1   OJCHB01SG           3            20.0
# 2  OJNYR23Y-8           3            20.0
# 3    OJUR01-7           3            20.0
# 4     OJBMS01           3            20.0

# %%
df_SI.tail(5)
# Out:
#               Data Cod. Vendedor Base Cod. Cliente Holding Cod. Cliente  \
# 415146  31/12/2024                  -                    -            -
# 415147  31/12/2024                  -                    -            -
# 415148  31/12/2024                  -                    -            -
# 415149  31/12/2024                  -                    -            -
# 415150  31/12/2024                  -                    -            -
#
#                Cod. Artigo  Quantidade  Valor Líq. EUR
# 415146                Sets           2            20.0
# 415147    Smartwatches Men           2            20.0
# 415148  Smartwatches Women           2            20.0
# 415149         Watches Men           2            20.0
# 415150       Watches Women           2            20.0
